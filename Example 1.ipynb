# %%
import alcdef_read as read
import numpy as np
import matplotlib.pyplot as plt

# %%
header, data = read.readfile('ALCDEF_1_Ceres.TXT')

print len(header)
print header[0]["FILTER"]
# Out:
# 5
# R

# %%
plt.scatter(data[1]["TIME"],data[1]["MAG"])
plt.xlabel("Julian Date")
plt.ylabel("Magnitude")
# Out:
# Text(0,0.5,'Magnitude')
